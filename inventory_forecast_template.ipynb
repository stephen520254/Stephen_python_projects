# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings('ignore')

# %%
df3 = pd.read_csv('gcasia_20_21.csv')
df1 = pd.read_csv('gcasia_19_20.csv')
df2 = pd.read_csv('gcasia_18_19.csv')

# %%
df3.columns = df3.columns.str.lower()
df3.columns = [' '.join(i.split()) for i in df3.columns]
df3.columns=df3.columns.str.replace(' ','_')

# %%
df2.columns = df2.columns.str.lower()
df2.columns = [' '.join(i.split()) for i in df2.columns]
df2.columns=df2.columns.str.replace(' ','_')

# %%
df1.columns = df1.columns.str.lower()
df1.columns = [' '.join(i.split()) for i in df1.columns]
df1.columns=df1.columns.str.replace(' ','_')

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((40541, 9), (35973, 12), (28880, 11))

# %%
df1.country.unique()
# Out:
# array(['INDONESIA', 'BELGIUM', 'MALAYSIA', 'MYANMAR', 'SINGAPORE',
#        'NEPAL', 'PHILIPPINES', 'THAILAND', 'VIETNAM', 'CAMBODIA',
#        'Australia', 'India', 'SRI LANKA', 'MONGOLIA', 'BANGLADESH',
#        'BHUTAN', 'BRUNEI DARUSSALAM', 'PAKISTAN', 'U.S.A.',
#        'GC Australasia Pty Ltd', 'AFGHANISTAN', 'KOREA', 'JAPAN',
#        'AUSTRALIA', 'LAO PDR'], dtype=object)

# %%
j=df1
m='MALAYSIA'
s = 'SINGAPORE'
p = 'PHILIPPINES'
t = 'THAILAND'
v = 'VIETNAM'
i = 'INDONESIA'
my = 'MYANMAR'
c = 'CAMBODIA'
b = 'BRUNEI DARUSSALAM'
p= 'PAKISTAN'
a = 'AFGHANISTAN'
l = 'LAO PDR'
req = (j.country==m)|(j.country==s)|(j.country==p)|(j.country==t)|(j.country==v)|(j.country==i)\
|(j.country==my)|(j.country==c)|(j.country==b)|(j.country==p)|(j.country==a)|(j.country==l)
df1=df1[req]

# %%
df1.shape
# Out:
# (11216, 9)

# %%
j=df2
m='MALAYSIA'
s = 'SINGAPORE'
p = 'PHILIPPINES'
t = 'THAILAND'
v = 'VIETNAM'
i = 'INDONESIA'
my = 'MYANMAR'
c = 'CAMBODIA'
b = 'BRUNEI DARUSSALAM'
p= 'PAKISTAN'
a = 'AFGHANISTAN'
l = 'LAO PDR'
req = (j.country==m)|(j.country==s)|(j.country==p)|(j.country==t)|(j.country==v)|(j.country==i)\
|(j.country==my)|(j.country==c)|(j.country==b)|(j.country==p)|(j.country==a)|(j.country==l)
df2=df2[req]

# %%
df2.shape
# Out:
# (10194, 12)

# %%
j=df3
m='MALAYSIA'
s = 'SINGAPORE'
p = 'PHILIPPINES'
t = 'THAILAND'
v = 'VIETNAM'
i = 'INDONESIA'
my = 'MYANMAR'
c = 'CAMBODIA'
b = 'BRUNEI DARUSSALAM'
p= 'PAKISTAN'
a = 'AFGHANISTAN'
l = 'LAO PDR'
req = (j.country==m)|(j.country==s)|(j.country==p)|(j.country==t)|(j.country==v)|(j.country==i)\
|(j.country==my)|(j.country==c)|(j.country==b)|(j.country==p)|(j.country==a)|(j.country==l)
df3=df3[req]

# %%
df3.shape
# Out:
# (7007, 11)

# %%
df1=df1[['product_code','product_packaging']]
df2=df2[['product_code','product_packaging']]
df3=df3[['product_code','product_packaging']]

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((11216, 2), (10194, 2), (7007, 2))

# %%
df = pd.concat([df1,df2,df3])

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                       product_code  \
# 0  0104A233-0020
# 1  0104A233-0030
# 2  0101E210-9000
# 3  0101B574-1000
# 4  0135F015-0030
#
#                                    product_packaging
# 0  Caviton 30g, Pink                             ...
# 1  Caviton 30g, White                            ...
# 2  Dentin Conditioner, 25g                       ...
# 3  Dentin Conditioner, 6g                        ...
# 4  EQUIA Forte Fil A3 50 Capsule                 ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28417 entries, 0 to 28416
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       28414 non-null  object
#  1   product_packaging  28417 non-null  object
# dtypes: object(2)
# memory usage: 444.1+ KB

# %%
df.product_code=df.product_code.astype(str)

# %%
df.product_code = [' '.join(i.split()) for i in df.product_code]
df.product_packaging = [' '.join(i.split()) for i in df.product_packaging]

# %%
df.head()
# Out:
#     product_code              product_packaging
# 0  0104A233-0020              Caviton 30g, Pink
# 1  0104A233-0030             Caviton 30g, White
# 2  0101E210-9000        Dentin Conditioner, 25g
# 3  0101B574-1000         Dentin Conditioner, 6g
# 4  0135F015-0030  EQUIA Forte Fil A3 50 Capsule

# %%
df=df.groupby(['product_code','product_packaging']).size().reset_index()
# df = df[~df.duplicated(keep='first')]
df = df[['product_code','product_packaging']]

# %%
df[df.product_code=='0136F032-0020']
# Out:
#       product_code               product_packaging
# 364  0136F032-0020  G-CEM LinkForce Starter Kit TR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       748 non-null    object
#  1   product_packaging  748 non-null    object
# dtypes: object(2)
# memory usage: 11.8+ KB

# %%
ml = pd.read_csv('masterlist.csv')

# %%
ml.head()
# Out:
#     product_code             classification  Unnamed: 2
# 0  CWG1000106002  Laboratory - Others Focus         NaN
# 1  CWG1000106003  Laboratory - Others Focus         NaN
# 2  CWG1000106004  Laboratory - Others Focus         NaN
# 3  CWG1000106005  Laboratory - Others Focus         NaN
# 4  CWG1000106006  Laboratory - Others Focus         NaN

# %%
del ml['Unnamed: 2']

# %%
ml.product_code=ml.product_code.astype(str)
ml.classification=ml.classification.astype(str)

# %%
ml.product_code = [' '.join(i.split()) for i in ml.product_code]
ml.classification= [' '.join(i.split()) for i in ml.classification]

# %%
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4555 entries, 0 to 4554
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_code    4555 non-null   object
#  1   classification  4555 non-null   object
# dtypes: object(2)
# memory usage: 71.3+ KB

# %%
for i, j in zip(ml.product_code, ml.classification):
    for s, p in zip(df.index, df.product_code):
        if p==i:
            df.loc[s,'classification']=j
        else:
            continue

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       748 non-null    object
#  1   product_packaging  748 non-null    object
#  2   classification     740 non-null    object
# dtypes: object(3)
# memory usage: 17.7+ KB

# %%
nan_rows = df[df['classification'].isnull()]

# %%
non_nan_rows = df[~df['classification'].isnull()]

# %%
df.shape, nan_rows.shape, non_nan_rows.shape
# Out:
# ((748, 3), (8, 3), (740, 3))

# %%
for i, d in zip(nan_rows.index, nan_rows.product_code):
    a = len(d)
    if a == 5:
        nan_rows.loc[i,'product_code']='0'+d
    elif a== 4:
        nan_rows.loc[i,'product_code']='00'+d
    elif a==3:
        nan_rows.loc[i,'product_code']='000'+d
    else:
        continue

# %%
nan_rows
# Out:
#     product_code                        product_packaging classification
# 486       012793                                 EXACLEAR            NaN
# 487       012793                              EXACLEAR AU            NaN
# 488       012793                 EXACLEAR AU (FOC-SAMPLE)            NaN
# 489       012903  everX Flow Syringe 3.7g Dentin Shade AU            NaN
# 541       004268                      EQUIA Coat 4ml Pack            NaN
# 542       004268                 EQUIA Coat 4ml Pack (DG)            NaN
# 640       877040                     Initial Mixing Plate            NaN
# 747       000nan               Sales Rebate for FY2019/20            NaN

# %%
df = pd.concat([nan_rows,non_nan_rows])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 748 entries, 486 to 746
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       748 non-null    object
#  1   product_packaging  748 non-null    object
#  2   classification     740 non-null    object
# dtypes: object(3)
# memory usage: 23.4+ KB

# %%
for i, j in zip(ml.product_code, ml.classification):
    for s, p in zip(df.index, df.product_code):
        if p==i:
            df.loc[s,'classification']=j
        else:
            continue

# %%
df.shape
# Out:
# (748, 3)

# %%
df.classification.unique()
# Out:
# array(['Operatory - Other Focus', 'Composite Restorative',
#        'GIC Restorative', nan, 'Non-9 Main', 'GIC Luting', 'Bonding',
#        'Misc. Lab', 'Preventive', 'Composite Luting',
#        'Laboratory - Others Focus', 'Digital Material', 'Ceramic',
#        'Digital Equipment'], dtype=object)

# %%
df.classification.value_counts().sum()
# Out:
# 746

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 748 entries, 486 to 746
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       748 non-null    object
#  1   product_packaging  748 non-null    object
#  2   classification     746 non-null    object
# dtypes: object(3)
# memory usage: 39.5+ KB

# %%
df[df['classification'].isnull()]
# Out:
#     product_code           product_packaging classification
# 640       877040        Initial Mixing Plate            NaN
# 747       000nan  Sales Rebate for FY2019/20            NaN

# %%
# find descrepancies in masterlist

ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4555 entries, 0 to 4554
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_code    4555 non-null   object
#  1   classification  4555 non-null   object
# dtypes: object(2)
# memory usage: 71.3+ KB

# %%
ml[ml.classification=='Ceramic']
# Out:
#      product_code classification
# 357     CWG000010        Ceramic
# 358     CWG000011        Ceramic
# 359     CWG000012        Ceramic
# 360     CWG000013        Ceramic
# 361     CWG000014        Ceramic
# 362     CWG000015        Ceramic
# 363     CWG000017        Ceramic
# 364     CWG000018        Ceramic
# 365     CWG000020        Ceramic
# 366     CWG000023        Ceramic
# 367     CWG000026        Ceramic
# 368     CWG000048        Ceramic
# 369     CWG000080        Ceramic
# 370     CWG000081        Ceramic
# 371     CWG000093        Ceramic
# 372     CWG000134        Ceramic
# 373     CWG000202        Ceramic
# 374     CWG000203        Ceramic
# 375     CWG000204        Ceramic
# 376     CWG000231        Ceramic
# 377     CWG000232        Ceramic
# 378     CWG000233        Ceramic
# 379     CWG000234        Ceramic
# 380     CWG000235        Ceramic
# 381     CWG000236        Ceramic
# 382     CWG000237        Ceramic
# 383     CWG000238        Ceramic
# ...

# %%
# found descrepancy in low index 994

ml.loc[994,'product_code']
# Out:
# '877040.00'

# %%
# remove trailing zeros after decimal point in string in row index 994

func = lambda n: n.rstrip('0').rstrip('.') if '.' in n else n

ml.product_code = [func(n) for n in ml.product_code]

ml.loc[994,'product_code']
# Out:
# '877040'

# %%
# run thru again to refine classification column

for i, j in zip(ml.product_code, ml.classification):
    for s, p in zip(df.index, df.product_code):
        if p==i:
            df.loc[s,'classification']=j
        else:
            continue

# %%
df[df['classification'].isnull()]
# Out:
#     product_code           product_packaging classification
# 747       000nan  Sales Rebate for FY2019/20            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 748 entries, 486 to 746
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       748 non-null    object
#  1   product_packaging  748 non-null    object
#  2   classification     747 non-null    object
# dtypes: object(3)
# memory usage: 39.5+ KB

# %%
df.loc[747,'classification']
# Out:
# nan

# %%
# drop nan row in row index 747

df.drop([747], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 747 entries, 486 to 746
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_code       747 non-null    object
#  1   product_packaging  747 non-null    object
#  2   classification     747 non-null    object
# dtypes: object(3)
# memory usage: 23.3+ KB

# %%
df=df.reset_index(drop=True)

# %%
df.head()
# Out:
#   product_code                        product_packaging  \
# 0       012793                                 EXACLEAR
# 1       012793                              EXACLEAR AU
# 2       012793                 EXACLEAR AU (FOC-SAMPLE)
# 3       012903  everX Flow Syringe 3.7g Dentin Shade AU
# 4       004268                      EQUIA Coat 4ml Pack
#
#             classification
# 0  Operatory - Other Focus
# 1  Operatory - Other Focus
# 2  Operatory - Other Focus
# 3    Composite Restorative
# 4          GIC Restorative

# %%
df.to_csv('inventory_forecast_v1.csv',index=False)

# %%
dff=pd.read_csv('inventory_forecast.csv')

# %%
dff.shape

# %%
df

# %%
ff = pd.DataFrame({'name':['john','mary','john','john','mary'],'brand':['toyota','volvo','toyota','merc','nissan']})
ff.groupby(['name','brand']).size().reset_index()

# %%
ff[~ff.duplicated(keep='first')]

# %%
ff
